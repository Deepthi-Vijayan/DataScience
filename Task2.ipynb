# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepthi-Vijayan/DataScience/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lets Grow More**
#
# **Task 2**
#
# Name : DEEPTHI VIJAYAN
#
# **Data Science Internship**
#
# Image to Pencil Sketch with Python
#
# **Description Of Task** :We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread("penguin.jpg")
plt.figure(figsize=(8,8))
plt.imshow(img1)
plt.show()

# %%
rgbimage3 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(rgbimage3)
plt.show()

# %%
grayimage3 = cv2.cvtColor(rgbimage3, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(grayimage3,cmap='gray')
plt.show()

# %% [markdown]
# **Converting the gray scale image in to a inverted image**

# %%
invtgrayimage3 =255 - grayimage3
plt.figure(figsize=(8,8))
plt.imshow(invtgrayimage3,cmap='gray')
plt.show()

# %% [markdown]
# **Bluring the inverted grayscale image using Gaussian Blur**

# %%
blurimage3 = cv2.GaussianBlur(invtgrayimage3, (21,21), 0)
plt.figure(figsize=(8,8))
plt.imshow(blurimage3,cmap='gray')
plt.show()

# %%
invtblurimage3 = 255 - blurimage3
plt.figure(figsize=(8,8))
plt.imshow(invtblurimage3,cmap='gray')
plt.show()

# %%
sketch1 = cv2.divide(grayimage3, invtblurimage3, scale=256.0)
plt.figure(figsize=(8,8))
plt.imshow(rgbimage3)
plt.figure(figsize=(8,8))
plt.imshow(sketch1,cmap='gray')
plt.show()
